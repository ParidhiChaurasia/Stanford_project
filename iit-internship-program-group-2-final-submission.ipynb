# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("/kaggle/input/maternal-and-child-health-monitoring-in-lmics/gee_features_10pct.csv")
# Out:
# /tmp/ipykernel_32/1970164018.py:1: DtypeWarning: Columns (6,7,27) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("/kaggle/input/maternal-and-child-health-monitoring-in-lmics/gee_features_10pct.csv")

# %%
df.shape
# Out:
# (12098, 11945)

# %%
X = df

# %%
df1 = df

# Read the second dataset
df2 = pd.read_csv('/kaggle/input/maternal-and-child-health-monitoring-in-lmics/training_label.csv')

# %%
sampledf = pd.read_csv('/kaggle/input/maternal-and-child-health-monitoring-in-lmics/sample submission.csv')

# %%
df3 = pd.merge(df1, df2, on='DHSID')

# %%
df3.shape
# Out:
# (10058, 11956)

# %%
total_nan_values = df3.isnull().sum().sum()

# Print the total number of NaN values
print("Total NaN values:", total_nan_values)
# Out:
# Total NaN values: 6015663

# %%
# Calculate the total number of values in the DataFrame
total_values = df3.size

# Count the total number of NaN values
total_nan_values = df3.isnull().sum().sum()

# Calculate the percentage of NaN values
percentage_nan_values = (total_nan_values / total_values) * 100

# Print the percentage of NaN values
print("Percentage of NaN values:", percentage_nan_values)
# Out:
# Percentage of NaN values: 5.0024869141382124

# %%
# Get duplicate column names
duplicate_columns = df3.columns[df3.columns.duplicated()]

# Drop columns with duplicate names
df3 = df3.drop(duplicate_columns, axis=1)

# %%
df3.shape
# Out:
# (10058, 11956)

# %%
# Separate the data for each label
label1_data = pd.DataFrame(df3['Mean_BMI'])
label2_data = pd.DataFrame(df3['Median_BMI'])
label3_data = pd.DataFrame(df3['Unmet_Need_Rate'])
label4_data = pd.DataFrame(df3['Under5_Mortality_Rate'])
label5_data = pd.DataFrame(df3['Skilled_Birth_Attendant_Rate'])
label6_data = pd.DataFrame(df3['Stunted_Rate'])


# Print the individual datasets
print(label1_data)
print(label2_data)
print(label3_data)
print(label4_data)
print(label5_data)
print(label6_data)
# Out:
#        Mean_BMI
# 0         21.67
# 1         19.62
# 2         20.07
# 3         21.64
# 4           NaN
# ...         ...
# 10053     22.94
# 10054     22.67
# 10055     30.40
# 10056     25.70
# 10057       NaN
#
# [10058 rows x 1 columns]
#        Median_BMI
# 0           20.44
# 1           20.22
# 2           20.83
# 3           20.07
# 4             NaN
# ...           ...
# 10053       23.14
# 10054       21.05
# 10055       31.56
# 10056       24.13
# 10057         NaN
#
# [10058 rows x 1 columns]
#        Unmet_Need_Rate
# 0                42.86
# 1                66.67
# 2                83.33
# 3                66.67
# 4                33.33
# ...                ...
# 10053             0.00
# 10054             5.56
# 10055             0.00
# 10056            17.65
# 10057            16.67
#
# [10058 rows x 1 columns]
#        Under5_Mortality_Rate
# 0                        NaN
# 1                        NaN
# 2                        NaN
# 3                      16.33
# ...

# %%
df4 = df3

# %%
# Specify the column range to print
start_column = 11945
end_column = 11955

# Print the specified columns
print(df4.iloc[:, start_column:end_column+1])
# Out:
#        DHSYEAR_y  DHSCLUST_y   LATNUM_y   LONGNUM_y  Mean_BMI  Median_BMI  \
# 0           2014    110884.0  23.570005   70.651418     21.67       20.44
# 1           2014     51523.0  25.520066   87.810497     19.62       20.22
# 2           2014    150534.0  24.277066   86.604189     20.07       20.83
# 3           2003       174.0  11.783420    7.623695     21.64       20.07
# 4           2008       205.0  16.060900  120.729230       NaN         NaN
# ...          ...         ...        ...         ...       ...         ...
# 10053       2014    320268.0  23.782248   91.235029     22.94       23.14
# 10054       2014    120410.0  29.061069   75.766470     22.67       21.05
# 10055       2008       765.0  29.196011   31.096641     30.40       31.56
# 10056       2000       614.0  -8.040578  -78.183586     25.70       24.13
# 10057       2007      1622.0  19.271805  -69.873362       NaN         NaN
#
#        Unmet_Need_Rate  Under5_Mortality_Rate  Skilled_Birth_Attendant_Rate  \
# ...

# %%
df4 = df4.drop(df4.columns[11945:11956], axis=1)

# %%
# Identify columns with categorical data
categorical_columns = df4.select_dtypes(include=['object']).columns.tolist()

# Print the categorical columns
print("Categorical columns:", categorical_columns)
# Out:
# Categorical columns: ['new_ind', 'ADM1FIPS', 'ADM1FIPSNA', 'ADM1NAME', 'ADM1SALBCO', 'ADM1SALBNA', 'CCFIPS', 'DATUM', 'DHSCC', 'DHSID', 'DHSREGNA', 'SOURCE', 'URBAN_RURA_x', 'ZONENA', 'key1']

# %%
for i in categorical_columns:
    column_name = i  # Replace 'ColumnName' with the actual name of the column
    unique_values = df4[column_name].unique()

    # Print the unique values
    print(i)
    print(unique_values)
    print("---------------------------------")
# Out:
# new_ind
# ['IA_2014_00110884' 'IA_2014_00051523' 'IA_2014_00150534' ...
#  'EG_2008_00000765' 'PE_2000_00000614' 'DR_2007_00001622']
# ---------------------------------
# ADM1FIPS
# [nan 'BG81' 'ML02' 'ET54' 'WA34' 'ZA04' 'ZA03' 'CM12' 'MZ09' 'BN10' 'GH02'
#  'EG04' 'EG13' 'ET53' 'CB18' 'JO22' 'NI30' 'RW15' 'EG28' 'ML01' 'CN02'
#  'CO34' 'JO15' 'NI32' 'NI50' 'ZA02' 'ET51' 'CO04' 'GT01' 'CO10' 'ET47'
#  'GT11' 'EG18' 'GT07' 'GH09' 'EG11' 'SG01' 'CO03' 'SG12' 'GH03' 'ZA07'
#  'GY12' 'GH08' 'RW11' 'GY10' 'CO25' 'ZI08' 'TO24' 'CM14' 'GH01' 'ZA06'
#  'ML07' 'EG01' 'GY19' 'JO9' 'CO19' 'CO29' 'NI16' 'ET45' 'AM02' 'SL02'
#  'EG12' 'NI27' 'GT08' 'MO50' 'NI54' 'CO08' 'LT13' 'CO21' 'WZ01' 'SG07'
#  'HA11' 'PK03' 'SG09' 'MZ02' 'NI43' 'BG84' 'EG20' 'NI22' 'BN14' 'MZ11'
#  'GT12' 'PE04' 'ET48' 'RW14' 'CO12' 'HO06' 'MZ03' 'TI04' 'GT04' 'LT16'
#  'SG10' 'CO27' 'EG09' 'CO02' 'MO49' 'ET52' 'ML06' 'ZA05' 'JO17' 'GB01'
#  'ML03' 'GT20' 'ET50' 'AM10' 'GH11' 'ZA10' 'TI01' 'ZA08' 'LT19' 'KE05'
# ...

# %%
# Specify the columns to drop
columns_to_drop = ['new_ind', 'ADM1FIPS', 'ADM1FIPSNA', 'ADM1NAME', 'ADM1SALBCO', 'ADM1SALBNA', 'CCFIPS', 'DATUM', 'DHSCC', 'DHSID', 'DHSREGNA', 'SOURCE','ZONENA' ,'key1']  

# Drop the specified columns
df4 = df4.drop(columns=columns_to_drop)

df4.shape
# Out:
# (10058, 11931)

# %%
# Specify the column to one-hot encode
column_to_encode = 'URBAN_RURA_x'  # Replace 'your_column' with the actual column name

# Perform one-hot encoding
one_hot_encoded = pd.get_dummies(df4[column_to_encode], prefix=column_to_encode)

# Concatenate the original DataFrame with the one-hot encoded column
df4 = pd.concat([df4, one_hot_encoded], axis=1)

# Drop the original column (optional)
df4 = df4.drop(column_to_encode, axis=1)

# %%
df4.shape
# Out:
# (10058, 11932)

# %%
total_nan_values = label1_data.isnull().sum().sum()

# Print the total number of NaN values
print("Total NaN values in Mean_BMI:", total_nan_values)

total_nan_values = label2_data.isnull().sum().sum()

# Print the total number of NaN values
print("Total NaN values in Median_BMI:", total_nan_values)

total_nan_values = label3_data.isnull().sum().sum()

# Print the total number of NaN values
print("Total NaN values in Unmet_Need_Rate:", total_nan_values)

total_nan_values = label4_data.isnull().sum().sum()

# Print the total number of NaN values
print("Total NaN values in Under5_Mortality_Rate:", total_nan_values)

total_nan_values = label5_data.isnull().sum().sum()

# Print the total number of NaN values
print("Total NaN values in Skilled_Birth_Attendant_Rate:", total_nan_values)

total_nan_values = label5_data.isnull().sum().sum()

# Print the total number of NaN values
print("Total NaN values in Stunted_Rate:", total_nan_values)
# Out:
# Total NaN values in Mean_BMI: 0
# Total NaN values in Median_BMI: 1957
# Total NaN values in Unmet_Need_Rate: 183
# Total NaN values in Under5_Mortality_Rate: 2839
# Total NaN values in Skilled_Birth_Attendant_Rate: 3189
# Total NaN values in Stunted_Rate: 3189

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import RandomForestRegressor

# %%
column_with_missing = label1_data['Mean_BMI']

# Create a mask for missing values
missing_mask = column_with_missing.isnull()

# Get the indices of missing values
missing_indices = column_with_missing[missing_mask].index.values

# Split the data into two groups: one with missing values and one without
data_with_missing = column_with_missing[missing_mask]
data_without_missing = column_with_missing[~missing_mask]

# Split into features and target variables
X_train = data_without_missing.index.values.reshape(-1, 1)
y_train = data_without_missing.values.flatten()

# Fit the Random Forest model
rf_model = RandomForestRegressor()
rf_model.fit(X_train, y_train)

# Predict missing values
missing_values = rf_model.predict(missing_indices.reshape(-1, 1))

# Create a copy of the original column
filled_column = column_with_missing.copy()

# Fill missing values in the copied column
filled_column[missing_indices] = missing_values

# Replace the original column with the filled values
label1_data['Mean_BMI'] = filled_column

# %%
total_nan_values = label1_data.isnull().sum().sum()

# Print the total number of NaN values
print("Total NaN values in Mean_BMI:", total_nan_values)
# Out:
# Total NaN values in Mean_BMI: 0

# %%
column_with_missing = label2_data['Median_BMI']

# Create a mask for missing values
missing_mask = column_with_missing.isnull()

# Get the indices of missing values
missing_indices = column_with_missing[missing_mask].index.values

# Split the data into two groups: one with missing values and one without
data_with_missing = column_with_missing[missing_mask]
data_without_missing = column_with_missing[~missing_mask]

# Split into features and target variables
X_train = data_without_missing.index.values.reshape(-1, 1)
y_train = data_without_missing.values.flatten()

# Fit the Random Forest model
rf_model = RandomForestRegressor()
rf_model.fit(X_train, y_train)

# Predict missing values
missing_values = rf_model.predict(missing_indices.reshape(-1, 1))

# Create a copy of the original column
filled_column = column_with_missing.copy()

# Fill missing values in the copied column
filled_column[missing_indices] = missing_values

# Replace the original column with the filled values
label2_data['Median_BMI'] = filled_column

# %%
column_with_missing = label3_data['Unmet_Need_Rate']

# Create a mask for missing values
missing_mask = column_with_missing.isnull()

# Get the indices of missing values
missing_indices = column_with_missing[missing_mask].index.values

# Split the data into two groups: one with missing values and one without
data_with_missing = column_with_missing[missing_mask]
data_without_missing = column_with_missing[~missing_mask]

# Split into features and target variables
X_train = data_without_missing.index.values.reshape(-1, 1)
y_train = data_without_missing.values.flatten()

# Fit the Random Forest model
rf_model = RandomForestRegressor()
rf_model.fit(X_train, y_train)

# Predict missing values
missing_values = rf_model.predict(missing_indices.reshape(-1, 1))

# Create a copy of the original column
filled_column = column_with_missing.copy()

# Fill missing values in the copied column
filled_column[missing_indices] = missing_values

# Replace the original column with the filled values
label3_data['Unmet_Need_Rate'] = filled_column

# %%
column_with_missing = label4_data['Under5_Mortality_Rate']

# Create a mask for missing values
missing_mask = column_with_missing.isnull()

# Get the indices of missing values
missing_indices = column_with_missing[missing_mask].index.values

# Split the data into two groups: one with missing values and one without
data_with_missing = column_with_missing[missing_mask]
data_without_missing = column_with_missing[~missing_mask]

# Split into features and target variables
X_train = data_without_missing.index.values.reshape(-1, 1)
y_train = data_without_missing.values.flatten()

# Fit the Random Forest model
rf_model = RandomForestRegressor()
rf_model.fit(X_train, y_train)

# Predict missing values
missing_values = rf_model.predict(missing_indices.reshape(-1, 1))

# Create a copy of the original column
filled_column = column_with_missing.copy()

# Fill missing values in the copied column
filled_column[missing_indices] = missing_values

# Replace the original column with the filled values
label4_data['Under5_Mortality_Rate'] = filled_column

# %%
column_with_missing = label5_data['Skilled_Birth_Attendant_Rate']

# Create a mask for missing values
missing_mask = column_with_missing.isnull()

# Get the indices of missing values
missing_indices = column_with_missing[missing_mask].index.values

# Split the data into two groups: one with missing values and one without
data_with_missing = column_with_missing[missing_mask]
data_without_missing = column_with_missing[~missing_mask]

# Split into features and target variables
X_train = data_without_missing.index.values.reshape(-1, 1)
y_train = data_without_missing.values.flatten()

# Fit the Random Forest model
rf_model = RandomForestRegressor()
rf_model.fit(X_train, y_train)

# Predict missing values
missing_values = rf_model.predict(missing_indices.reshape(-1, 1))

# Create a copy of the original column
filled_column = column_with_missing.copy()

# Fill missing values in the copied column
filled_column[missing_indices] = missing_values

# Replace the original column with the filled values
label5_data['Skilled_Birth_Attendant_Rate'] = filled_column

# %%
column_with_missing = label6_data['Stunted_Rate']

# Create a mask for missing values
missing_mask = column_with_missing.isnull()

# Get the indices of missing values
missing_indices = column_with_missing[missing_mask].index.values

# Split the data into two groups: one with missing values and one without
data_with_missing = column_with_missing[missing_mask]
data_without_missing = column_with_missing[~missing_mask]

# Split into features and target variables
X_train = data_without_missing.index.values.reshape(-1, 1)
y_train = data_without_missing.values.flatten()

# Fit the Random Forest model
rf_model = RandomForestRegressor()
rf_model.fit(X_train, y_train)

# Predict missing values
missing_values = rf_model.predict(missing_indices.reshape(-1, 1))

# Create a copy of the original column
filled_column = column_with_missing.copy()

# Fill missing values in the copied column
filled_column[missing_indices] = missing_values

# Replace the original column with the filled values
label6_data['Stunted_Rate'] = filled_column

# %%
total_nan_values = label1_data.isnull().sum().sum()

# Print the total number of NaN values
print("Total NaN values in Mean_BMI:", total_nan_values)

total_nan_values = label2_data.isnull().sum().sum()

# Print the total number of NaN values
print("Total NaN values in Median_BMI:", total_nan_values)

total_nan_values = label3_data.isnull().sum().sum()

# Print the total number of NaN values
print("Total NaN values in Unmet_Need_Rate:", total_nan_values)

total_nan_values = label4_data.isnull().sum().sum()

# Print the total number of NaN values
print("Total NaN values in Under5_Mortality_Rate:", total_nan_values)

total_nan_values = label5_data.isnull().sum().sum()

# Print the total number of NaN values
print("Total NaN values in Skilled_Birth_Attendant_Rate:", total_nan_values)

total_nan_values = label5_data.isnull().sum().sum()

# Print the total number of NaN values
print("Total NaN values in Stunted_Rate:", total_nan_values)
# Out:
# Total NaN values in Mean_BMI: 0
# Total NaN values in Median_BMI: 0
# Total NaN values in Unmet_Need_Rate: 0
# Total NaN values in Under5_Mortality_Rate: 0
# Total NaN values in Skilled_Birth_Attendant_Rate: 0
# Total NaN values in Stunted_Rate: 0

# %%
print(label1_data.mean())
# Out:
# Mean_BMI    23.362182
# dtype: float64

# %%
df5 = df4
df5 = df5[:1000]
y1 = label1_data[:1000]
print(y1)
# Out:
#      Mean_BMI
# 0     21.6700
# 1     19.6200
# 2     20.0700
# 3     21.6400
# 4     21.9206
# ..        ...
# 995   24.8700
# 996   22.0700
# 997   19.7900
# 998   19.5600
# 999   25.2100
#
# [1000 rows x 1 columns]

# %%
# df4 = df4.fillna(df4.mean())
df5 = df5.fillna(0)

# %%
# Separate the features and target variable
X = df5
y = y1['Mean_BMI']

# Create a Random Forest regressor
# Create a Random Forest regressor
rf = RandomForestRegressor()

# Fit the Random Forest model
rf.fit(X, y)

# Get feature importances
feature_importances = rf.feature_importances_


# # Create a DataFrame with feature names and importances
# feature_importances = pd.DataFrame({'Feature': X.columns, 'Importance': importances})

# # Sort the features by importance in descending order
# feature_importances = feature_importances.sort_values('Importance', ascending=False)

# # Print the feature importances
# print(feature_importances)

# %%
sorted_feature_importances = sorted(zip(feature_importances, X.columns), reverse=True)

# Select the top k important features (e.g., k=10)
k = 40
selected_features = [feature for importance, feature in sorted_feature_importances[:k]]

# %%
df6 = df4[selected_features]

# %%
print(selected_features)
# Out:
# ['bio18_max@WORLDCLIM/V1/BIO', 'Lifted_Index_Mean_Mean_min_max@MODIS/061/MOD08_M3&timestamped', 'Lifted_Index_Mean_Mean_min_min@MODIS/061/MOD08_M3&timestamped', 'URBAN_RURA_x_U', 'LONGNUM_x', 'Lifted_Index_QA_Mean_Mean_min_max@MODIS/061/MOD08_M3&timestamped', 'URBAN_RURA_x_R', 'Lifted_Index_QA_Mean_Mean_min_min@MODIS/061/MOD08_M3&timestamped', 'Cloud_Top_Pressure_Nadir_Mean_Mean_min_max@MODIS/061/MOD08_M3&timestamped', 'surface_latent_heat_flux_min_max@ECMWF/ERA5_LAND/MONTHLY&timestamped', 'TIMEOFDAY_mean@NOAA/CDR/AVHRR/NDVI/V5&timestamped', 'Lifted_Index_QA_Mean_Mean_median@MODIS/061/MOD08_M3&timestamped', 'bio18_min@WORLDCLIM/V1/BIO', 'total_evaporation_mean@ECMWF/ERA5_LAND/MONTHLY&timestamped', 'Aerosol_Optical_Depth_Land_Ocean_Std_Deviation_Mean_median@MODIS/061/MOD08_M3&timestamped', 'TIMEOFDAY_median@NOAA/CDR/AVHRR/NDVI/V5&timestamped', 'Cloud_Effective_Radius_16_PCL_Liquid_Mean_Mean_min_min@MODIS/061/MOD08_M3&timestamped', 'Lifted_Index_Mean_Mean_mean@MODIS/061/MOD08_M3&timest
# ...

# %%
df6.shape
# Out:
# (10058, 40)

# %%
df6.head()
# Out:
#    bio18_max@WORLDCLIM/V1/BIO  \
# 0                         193
# 1                         665
# 2                         245
# 3                         113
# 4                         435
#
#    Lifted_Index_Mean_Mean_min_max@MODIS/061/MOD08_M3&timestamped  \
# 0                                               -277
# 1                                               -462
# 2                                               -461
# 3                                                 33
# 4                                               -136
#
#    Lifted_Index_Mean_Mean_min_min@MODIS/061/MOD08_M3&timestamped  \
# 0                                               -277
# 1                                               -462
# 2                                               -461
# 3                                                 33
# 4                                               -136
#
#    URBAN_RURA_x_U   LONGNUM_x  \
# 0               1   70.651420
# 1               0   87.810490
# ...

# %%
# Calculate the mean of a column
column_mean = label1_data['Mean_BMI'].mean()

# Print the mean value
print(column_mean)
# Out:
# 23.362181835354942

# %%
import pandas as pd
from sklearn.linear_model import LinearRegression, Ridge, Lasso, ElasticNet
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor
from sklearn.svm import SVR
from sklearn.neural_network import MLPRegressor
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split




# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(df6, label1_data['Mean_BMI'], test_size=0.2, random_state=42)

# Initialize the regressor models
linear_reg = LinearRegression()
ridge_reg = Ridge()
lasso_reg = Lasso()
elastic_net_reg = ElasticNet()
decision_tree_reg = DecisionTreeRegressor()
random_forest_reg = RandomForestRegressor()
gradient_boost_reg = GradientBoostingRegressor()
svr = SVR()
mlp_reg = MLPRegressor()

# Fit the models
linear_reg.fit(X_train, y_train)
ridge_reg.fit(X_train, y_train)
lasso_reg.fit(X_train, y_train)
elastic_net_reg.fit(X_train, y_train)
decision_tree_reg.fit(X_train, y_train)
random_forest_reg.fit(X_train, y_train)
gradient_boost_reg.fit(X_train, y_train)
svr.fit(X_train, y_train)
mlp_reg.fit(X_train, y_train)

# Make predictions
linear_reg_preds = linear_reg.predict(X_test)
ridge_reg_preds = ridge_reg.predict(X_test)
lasso_reg_preds = lasso_reg.predict(X_test)
elastic_net_reg_preds = elastic_net_reg.predict(X_test)
decision_tree_reg_preds = decision_tree_reg.predict(X_test)
random_forest_reg_preds = random_forest_reg.predict(X_test)
gradient_boost_reg_preds = gradient_boost_reg.predict(X_test)
svr_preds = svr.predict(X_test)
mlp_reg_preds = mlp_reg.predict(X_test)

# Calculate mean squared error for each model
linear_reg_mse = mean_squared_error(y_test, linear_reg_preds)
ridge_reg_mse = mean_squared_error(y_test, ridge_reg_preds)
lasso_reg_mse = mean_squared_error(y_test, lasso_reg_preds)
elastic_net_reg_mse = mean_squared_error(y_test, elastic_net_reg_preds)
decision_tree_reg_mse = mean_squared_error(y_test, decision_tree_reg_preds)
random_forest_reg_mse = mean_squared_error(y_test, random_forest_reg_preds)
gradient_boost_reg_mse = mean_squared_error(y_test, gradient_boost_reg_preds)
svr_mse = mean_squared_error(y_test, svr_preds)
mlp_reg_mse = mean_squared_error(y_test, mlp_reg_preds)

# Print mean squared error for each model
print("Linear Regression MSE:", linear_reg_mse)
print("Ridge Regression MSE:", ridge_reg_mse)
print("Lasso Regression MSE:", lasso_reg_mse)
print("Elastic Net Regression MSE:", elastic_net_reg_mse)
print("Decision Tree Regression MSE:", decision_tree_reg_mse)
print("Random Forest Regression MSE:", random_forest_reg_mse)
print("Gradient Boosting Regression MSE:", gradient_boost_reg_mse)
print("SVR MSE:", svr_mse)
print("MLP Regression MSE:", mlp_reg_mse)
# Out:
# /opt/conda/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:216: LinAlgWarning: Ill-conditioned matrix (rcond=7.91767e-18): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# /opt/conda/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.401e+03, tolerance: 9.211e+00
#   model = cd_fast.enet_coordinate_descent(
# /opt/conda/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.089e+04, tolerance: 9.211e+00
#   model = cd_fast.enet_coordinate_descent(
# Linear Regression MSE: 7.827826074669266
# ...

# %%
sampledf.head()
# Out:
#             DHSID  Mean_BMI  Median_BMI  Unmet_Need_Rate  \
# 0  AL200800000003        20          20               50
# 1  AL200800000005        20          20               50
# 2  AL200800000007        20          20               50
# 3  AL200800000008        20          20               50
# 4  AL200800000009        20          20               50
#
#    Under5_Mortality_Rate  Skilled_Birth_Attendant_Rate  Stunted_Rate
# 0                     50                            50            50
# 1                     50                            50            50
# 2                     50                            50            50
# 3                     50                            50            50
# 4                     50                            50            50

# %%
new_df = pd.DataFrame(sampledf.values[:, 0])

# %%
new_df = new_df.rename(columns={new_df.columns[0]: 'DHSID'})

# %%
new_df.head()
# Out:
#             DHSID
# 0  AL200800000003
# 1  AL200800000005
# 2  AL200800000007
# 3  AL200800000008
# 4  AL200800000009

# %%
merged_df = pd.merge(new_df,df, on='DHSID', how='inner')

# %%
merged_df.shape
# Out:
# (1592, 11945)

# %%
 new_df2 = merged_df

# %%
# Specify the columns to drop
columns_to_drop = ['new_ind', 'ADM1FIPS', 'ADM1FIPSNA', 'ADM1NAME', 'ADM1SALBCO', 'ADM1SALBNA', 'CCFIPS', 'DATUM', 'DHSCC', 'DHSID', 'DHSREGNA', 'SOURCE','ZONENA' ,'key1']  

# Drop the specified columns
new_df2 =  new_df2.drop(columns=columns_to_drop)

new_df2.shape
# Out:
# (1592, 11931)

# %%
new_df2 = new_df2.rename(columns={'URBAN_RURA': 'URBAN_RURA_x'})

# %%
# Specify the column to one-hot encode
column_to_encode = 'URBAN_RURA_x'  # Replace 'your_column' with the actual column name

# Perform one-hot encoding
one_hot_encoded = pd.get_dummies(new_df2[column_to_encode], prefix=column_to_encode)

# Concatenate the original DataFrame with the one-hot encoded column
new_df2 = pd.concat([new_df2, one_hot_encoded], axis=1)

# Drop the original column (optional)
new_df2 = new_df2.drop(column_to_encode, axis=1)

# %%
new_df2 = new_df2.rename(columns={'DHSYEAR': 'DHSYEAR_x'})

# %%
new_df2 = new_df2.rename(columns={'LONGNUM': 'LONGNUM_x'})

# %%
new_df2 = new_df2[selected_features]

# %%
# Generate predictions from the Random Forest model
predictions = random_forest_reg.predict(new_df2)

# Create a DataFrame with the predictions
df_predictions_mean = pd.DataFrame(predictions, columns=['Mean_BMI'])

# %%
df_predictions_mean.shape
# Out:
# (1592, 1)

# %%
df_predictions.head()
# Out:
#     Mean_BMI
# 0  25.590246
# 1  24.351282
# 2  25.712790
# 3  24.574885
# 4  25.214574

# %%
# Calculate the mean of a column
column_mean = label2_data['Median_BMI'].mean()

# Print the mean value
print(column_mean)
# Out:
# 22.89996492841519

# %%
import pandas as pd
from sklearn.linear_model import LinearRegression, Ridge, Lasso, ElasticNet
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor
from sklearn.svm import SVR
from sklearn.neural_network import MLPRegressor
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split




# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(df6, label2_data['Median_BMI'], test_size=0.2, random_state=42)

# Initialize the regressor models
linear_reg = LinearRegression()
ridge_reg = Ridge()
lasso_reg = Lasso()
elastic_net_reg = ElasticNet()
decision_tree_reg = DecisionTreeRegressor()
random_forest_reg = RandomForestRegressor()
gradient_boost_reg = GradientBoostingRegressor()
svr = SVR()
mlp_reg = MLPRegressor()

# Fit the models
linear_reg.fit(X_train, y_train)
ridge_reg.fit(X_train, y_train)
lasso_reg.fit(X_train, y_train)
elastic_net_reg.fit(X_train, y_train)
decision_tree_reg.fit(X_train, y_train)
random_forest_reg.fit(X_train, y_train)
gradient_boost_reg.fit(X_train, y_train)
svr.fit(X_train, y_train)
mlp_reg.fit(X_train, y_train)

# Make predictions
linear_reg_preds = linear_reg.predict(X_test)
ridge_reg_preds = ridge_reg.predict(X_test)
lasso_reg_preds = lasso_reg.predict(X_test)
elastic_net_reg_preds = elastic_net_reg.predict(X_test)
decision_tree_reg_preds = decision_tree_reg.predict(X_test)
random_forest_reg_preds = random_forest_reg.predict(X_test)
gradient_boost_reg_preds = gradient_boost_reg.predict(X_test)
svr_preds = svr.predict(X_test)
mlp_reg_preds = mlp_reg.predict(X_test)

# Calculate mean squared error for each model
linear_reg_mse = mean_squared_error(y_test, linear_reg_preds)
ridge_reg_mse = mean_squared_error(y_test, ridge_reg_preds)
lasso_reg_mse = mean_squared_error(y_test, lasso_reg_preds)
elastic_net_reg_mse = mean_squared_error(y_test, elastic_net_reg_preds)
decision_tree_reg_mse = mean_squared_error(y_test, decision_tree_reg_preds)
random_forest_reg_mse = mean_squared_error(y_test, random_forest_reg_preds)
gradient_boost_reg_mse = mean_squared_error(y_test, gradient_boost_reg_preds)
svr_mse = mean_squared_error(y_test, svr_preds)
mlp_reg_mse = mean_squared_error(y_test, mlp_reg_preds)

# Print mean squared error for each model
print("Linear Regression MSE:", linear_reg_mse)
print("Ridge Regression MSE:", ridge_reg_mse)
print("Lasso Regression MSE:", lasso_reg_mse)
print("Elastic Net Regression MSE:", elastic_net_reg_mse)
print("Decision Tree Regression MSE:", decision_tree_reg_mse)
print("Random Forest Regression MSE:", random_forest_reg_mse)
print("Gradient Boosting Regression MSE:", gradient_boost_reg_mse)
print("SVR MSE:", svr_mse)
print("MLP Regression MSE:", mlp_reg_mse)
# Out:
# /opt/conda/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:216: LinAlgWarning: Ill-conditioned matrix (rcond=7.91767e-18): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# /opt/conda/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.844e+04, tolerance: 9.611e+00
#   model = cd_fast.enet_coordinate_descent(
# /opt/conda/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.435e+04, tolerance: 9.611e+00
#   model = cd_fast.enet_coordinate_descent(
# Linear Regression MSE: 8.817143305507939
# ...

# %%
# Generate predictions from the Random Forest model
predictions = random_forest_reg.predict(new_df2)

# Create a DataFrame with the predictions
df_predictions_median = pd.DataFrame(predictions, columns=['Median_BMI'])

# %%
df_predictions_median.head()
# Out:
#    Median_BMI
# 0   24.647781
# 1   24.079521
# 2   24.835842
# 3   24.494444
# 4   25.001463

# %%
# Calculate the mean of a column
column_mean = label3_data['Unmet_Need_Rate'].mean()

# Print the mean value
print(column_mean)



import pandas as pd
from sklearn.linear_model import LinearRegression, Ridge, Lasso, ElasticNet
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor
from sklearn.svm import SVR
from sklearn.neural_network import MLPRegressor
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split




# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(df6, label3_data['Unmet_Need_Rate'], test_size=0.2, random_state=42)

# Initialize the regressor models
linear_reg = LinearRegression()
ridge_reg = Ridge()
lasso_reg = Lasso()
elastic_net_reg = ElasticNet()
decision_tree_reg = DecisionTreeRegressor()
random_forest_reg = RandomForestRegressor()
gradient_boost_reg = GradientBoostingRegressor()
svr = SVR()
mlp_reg = MLPRegressor()

# Fit the models
linear_reg.fit(X_train, y_train)
ridge_reg.fit(X_train, y_train)
lasso_reg.fit(X_train, y_train)
elastic_net_reg.fit(X_train, y_train)
decision_tree_reg.fit(X_train, y_train)
random_forest_reg.fit(X_train, y_train)
gradient_boost_reg.fit(X_train, y_train)
svr.fit(X_train, y_train)
mlp_reg.fit(X_train, y_train)

# Make predictions
linear_reg_preds = linear_reg.predict(X_test)
ridge_reg_preds = ridge_reg.predict(X_test)
lasso_reg_preds = lasso_reg.predict(X_test)
elastic_net_reg_preds = elastic_net_reg.predict(X_test)
decision_tree_reg_preds = decision_tree_reg.predict(X_test)
random_forest_reg_preds = random_forest_reg.predict(X_test)
gradient_boost_reg_preds = gradient_boost_reg.predict(X_test)
svr_preds = svr.predict(X_test)
mlp_reg_preds = mlp_reg.predict(X_test)

# Calculate mean squared error for each model
linear_reg_mse = mean_squared_error(y_test, linear_reg_preds)
ridge_reg_mse = mean_squared_error(y_test, ridge_reg_preds)
lasso_reg_mse = mean_squared_error(y_test, lasso_reg_preds)
elastic_net_reg_mse = mean_squared_error(y_test, elastic_net_reg_preds)
decision_tree_reg_mse = mean_squared_error(y_test, decision_tree_reg_preds)
random_forest_reg_mse = mean_squared_error(y_test, random_forest_reg_preds)
gradient_boost_reg_mse = mean_squared_error(y_test, gradient_boost_reg_preds)
svr_mse = mean_squared_error(y_test, svr_preds)
mlp_reg_mse = mean_squared_error(y_test, mlp_reg_preds)

# Print mean squared error for each model
print("Linear Regression MSE:", linear_reg_mse)
print("Ridge Regression MSE:", ridge_reg_mse)
print("Lasso Regression MSE:", lasso_reg_mse)
print("Elastic Net Regression MSE:", elastic_net_reg_mse)
print("Decision Tree Regression MSE:", decision_tree_reg_mse)
print("Random Forest Regression MSE:", random_forest_reg_mse)
print("Gradient Boosting Regression MSE:", gradient_boost_reg_mse)
print("SVR MSE:", svr_mse)
print("MLP Regression MSE:", mlp_reg_mse)

# Generate predictions from the Random Forest model
predictions = random_forest_reg.predict(new_df2)

# Create a DataFrame with the predictions
df_predictions_3 = pd.DataFrame(predictions, columns=['Unmet_Need_Rate'])

df_predictions_3.head(200)
# Out:
# 33.79767670013919
# /opt/conda/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:216: LinAlgWarning: Ill-conditioned matrix (rcond=7.91767e-18): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# /opt/conda/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.197e+06, tolerance: 7.073e+02
#   model = cd_fast.enet_coordinate_descent(
# /opt/conda/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.213e+06, tolerance: 7.073e+02
#   model = cd_fast.enet_coordinate_descent(
# ...

# %%
# Calculate the mean of a column
column_mean = label4_data['Under5_Mortality_Rate'].mean()

# Print the mean value
print(column_mean)



import pandas as pd
from sklearn.linear_model import LinearRegression, Ridge, Lasso, ElasticNet
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor
from sklearn.svm import SVR
from sklearn.neural_network import MLPRegressor
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split




# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(df6, label4_data['Under5_Mortality_Rate'], test_size=0.2, random_state=42)

# Initialize the regressor models
linear_reg = LinearRegression()
ridge_reg = Ridge()
lasso_reg = Lasso()
elastic_net_reg = ElasticNet()
decision_tree_reg = DecisionTreeRegressor()
random_forest_reg = RandomForestRegressor()
gradient_boost_reg = GradientBoostingRegressor()
svr = SVR()
mlp_reg = MLPRegressor()

# Fit the models
linear_reg.fit(X_train, y_train)
ridge_reg.fit(X_train, y_train)
lasso_reg.fit(X_train, y_train)
elastic_net_reg.fit(X_train, y_train)
decision_tree_reg.fit(X_train, y_train)
random_forest_reg.fit(X_train, y_train)
gradient_boost_reg.fit(X_train, y_train)
svr.fit(X_train, y_train)
mlp_reg.fit(X_train, y_train)

# Make predictions
linear_reg_preds = linear_reg.predict(X_test)
ridge_reg_preds = ridge_reg.predict(X_test)
lasso_reg_preds = lasso_reg.predict(X_test)
elastic_net_reg_preds = elastic_net_reg.predict(X_test)
decision_tree_reg_preds = decision_tree_reg.predict(X_test)
random_forest_reg_preds = random_forest_reg.predict(X_test)
gradient_boost_reg_preds = gradient_boost_reg.predict(X_test)
svr_preds = svr.predict(X_test)
mlp_reg_preds = mlp_reg.predict(X_test)

# Calculate mean squared error for each model
linear_reg_mse = mean_squared_error(y_test, linear_reg_preds)
ridge_reg_mse = mean_squared_error(y_test, ridge_reg_preds)
lasso_reg_mse = mean_squared_error(y_test, lasso_reg_preds)
elastic_net_reg_mse = mean_squared_error(y_test, elastic_net_reg_preds)
decision_tree_reg_mse = mean_squared_error(y_test, decision_tree_reg_preds)
random_forest_reg_mse = mean_squared_error(y_test, random_forest_reg_preds)
gradient_boost_reg_mse = mean_squared_error(y_test, gradient_boost_reg_preds)
svr_mse = mean_squared_error(y_test, svr_preds)
mlp_reg_mse = mean_squared_error(y_test, mlp_reg_preds)

# Print mean squared error for each model
print("Linear Regression MSE:", linear_reg_mse)
print("Ridge Regression MSE:", ridge_reg_mse)
print("Lasso Regression MSE:", lasso_reg_mse)
print("Elastic Net Regression MSE:", elastic_net_reg_mse)
print("Decision Tree Regression MSE:", decision_tree_reg_mse)
print("Random Forest Regression MSE:", random_forest_reg_mse)
print("Gradient Boosting Regression MSE:", gradient_boost_reg_mse)
print("SVR MSE:", svr_mse)
print("MLP Regression MSE:", mlp_reg_mse)

# Generate predictions from the Random Forest model
predictions = random_forest_reg.predict(new_df2)

# Create a DataFrame with the predictions
df_predictions_4 = pd.DataFrame(predictions, columns=['Under5_Mortality_Rate'])

df_predictions_4.head(200)
# Out:
# 9.012779240405647
# /opt/conda/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:216: LinAlgWarning: Ill-conditioned matrix (rcond=7.91767e-18): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# /opt/conda/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.815e+05, tolerance: 4.115e+01
#   model = cd_fast.enet_coordinate_descent(
# /opt/conda/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.891e+05, tolerance: 4.115e+01
#   model = cd_fast.enet_coordinate_descent(
# ...

# %%
# Separate the data for each label
label1_data = pd.DataFrame(df3['Mean_BMI'])
label2_data = pd.DataFrame(df3['Median_BMI'])
label3_data = pd.DataFrame(df3['Unmet_Need_Rate'])
label4_data = pd.DataFrame(df3['Under5_Mortality_Rate'])
label5_data = pd.DataFrame(df3['Skilled_Birth_Attendant_Rate'])
label6_data = pd.DataFrame(df3['Stunted_Rate'])

# %%
# Calculate the mean of a column
column_mean = label5_data['Skilled_Birth_Attendant_Rate'].mean()

# Print the mean value
print(column_mean)



import pandas as pd
from sklearn.linear_model import LinearRegression, Ridge, Lasso, ElasticNet
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor
from sklearn.svm import SVR
from sklearn.neural_network import MLPRegressor
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split




# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(df6, label5_data['Skilled_Birth_Attendant_Rate'], test_size=0.2, random_state=42)

# Initialize the regressor models
linear_reg = LinearRegression()
ridge_reg = Ridge()
lasso_reg = Lasso()
elastic_net_reg = ElasticNet()
decision_tree_reg = DecisionTreeRegressor()
random_forest_reg = RandomForestRegressor()
gradient_boost_reg = GradientBoostingRegressor()
svr = SVR()
mlp_reg = MLPRegressor()

# Fit the models
linear_reg.fit(X_train, y_train)
ridge_reg.fit(X_train, y_train)
lasso_reg.fit(X_train, y_train)
elastic_net_reg.fit(X_train, y_train)
decision_tree_reg.fit(X_train, y_train)
random_forest_reg.fit(X_train, y_train)
gradient_boost_reg.fit(X_train, y_train)
svr.fit(X_train, y_train)
mlp_reg.fit(X_train, y_train)

# Make predictions
linear_reg_preds = linear_reg.predict(X_test)
ridge_reg_preds = ridge_reg.predict(X_test)
lasso_reg_preds = lasso_reg.predict(X_test)
elastic_net_reg_preds = elastic_net_reg.predict(X_test)
decision_tree_reg_preds = decision_tree_reg.predict(X_test)
random_forest_reg_preds = random_forest_reg.predict(X_test)
gradient_boost_reg_preds = gradient_boost_reg.predict(X_test)
svr_preds = svr.predict(X_test)
mlp_reg_preds = mlp_reg.predict(X_test)

# Calculate mean squared error for each model
linear_reg_mse = mean_squared_error(y_test, linear_reg_preds)
ridge_reg_mse = mean_squared_error(y_test, ridge_reg_preds)
lasso_reg_mse = mean_squared_error(y_test, lasso_reg_preds)
elastic_net_reg_mse = mean_squared_error(y_test, elastic_net_reg_preds)
decision_tree_reg_mse = mean_squared_error(y_test, decision_tree_reg_preds)
random_forest_reg_mse = mean_squared_error(y_test, random_forest_reg_preds)
gradient_boost_reg_mse = mean_squared_error(y_test, gradient_boost_reg_preds)
svr_mse = mean_squared_error(y_test, svr_preds)
mlp_reg_mse = mean_squared_error(y_test, mlp_reg_preds)

# Print mean squared error for each model
print("Linear Regression MSE:", linear_reg_mse)
print("Ridge Regression MSE:", ridge_reg_mse)
print("Lasso Regression MSE:", lasso_reg_mse)
print("Elastic Net Regression MSE:", elastic_net_reg_mse)
print("Decision Tree Regression MSE:", decision_tree_reg_mse)
print("Random Forest Regression MSE:", random_forest_reg_mse)
print("Gradient Boosting Regression MSE:", gradient_boost_reg_mse)
print("SVR MSE:", svr_mse)
print("MLP Regression MSE:", mlp_reg_mse)

# Generate predictions from the Random Forest model
predictions = random_forest_reg.predict(new_df2)

# Create a DataFrame with the predictions
df_predictions_5 = pd.DataFrame(predictions, columns=['Skilled_Birth_Attendant_Rate'])

df_predictions_5.head(200)
# Out:
# 64.5325032909127
# /opt/conda/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:216: LinAlgWarning: Ill-conditioned matrix (rcond=7.91767e-18): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# /opt/conda/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.679e+06, tolerance: 8.379e+02
#   model = cd_fast.enet_coordinate_descent(
# /opt/conda/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.762e+06, tolerance: 8.379e+02
#   model = cd_fast.enet_coordinate_descent(
# Linear Regression MSE: 862.6530872865304
# ...

# %%
# Calculate the mean of a column
column_mean = label6_data['Stunted_Rate'].mean()

# Print the mean value
print(column_mean)



import pandas as pd
from sklearn.linear_model import LinearRegression, Ridge, Lasso, ElasticNet
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor
from sklearn.svm import SVR
from sklearn.neural_network import MLPRegressor
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split




# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(df6, label6_data['Stunted_Rate'], test_size=0.2, random_state=42)

# Initialize the regressor models
linear_reg = LinearRegression()
ridge_reg = Ridge()
lasso_reg = Lasso()
elastic_net_reg = ElasticNet()
decision_tree_reg = DecisionTreeRegressor()
random_forest_reg = RandomForestRegressor()
gradient_boost_reg = GradientBoostingRegressor()
svr = SVR()
mlp_reg = MLPRegressor()

# Fit the models
linear_reg.fit(X_train, y_train)
ridge_reg.fit(X_train, y_train)
lasso_reg.fit(X_train, y_train)
elastic_net_reg.fit(X_train, y_train)
decision_tree_reg.fit(X_train, y_train)
random_forest_reg.fit(X_train, y_train)
gradient_boost_reg.fit(X_train, y_train)
svr.fit(X_train, y_train)
mlp_reg.fit(X_train, y_train)

# Make predictions
linear_reg_preds = linear_reg.predict(X_test)
ridge_reg_preds = ridge_reg.predict(X_test)
lasso_reg_preds = lasso_reg.predict(X_test)
elastic_net_reg_preds = elastic_net_reg.predict(X_test)
decision_tree_reg_preds = decision_tree_reg.predict(X_test)
random_forest_reg_preds = random_forest_reg.predict(X_test)
gradient_boost_reg_preds = gradient_boost_reg.predict(X_test)
svr_preds = svr.predict(X_test)
mlp_reg_preds = mlp_reg.predict(X_test)

# Calculate mean squared error for each model
linear_reg_mse = mean_squared_error(y_test, linear_reg_preds)
ridge_reg_mse = mean_squared_error(y_test, ridge_reg_preds)
lasso_reg_mse = mean_squared_error(y_test, lasso_reg_preds)
elastic_net_reg_mse = mean_squared_error(y_test, elastic_net_reg_preds)
decision_tree_reg_mse = mean_squared_error(y_test, decision_tree_reg_preds)
random_forest_reg_mse = mean_squared_error(y_test, random_forest_reg_preds)
gradient_boost_reg_mse = mean_squared_error(y_test, gradient_boost_reg_preds)
svr_mse = mean_squared_error(y_test, svr_preds)
mlp_reg_mse = mean_squared_error(y_test, mlp_reg_preds)

# Print mean squared error for each model
print("Linear Regression MSE:", linear_reg_mse)
print("Ridge Regression MSE:", ridge_reg_mse)
print("Lasso Regression MSE:", lasso_reg_mse)
print("Elastic Net Regression MSE:", elastic_net_reg_mse)
print("Decision Tree Regression MSE:", decision_tree_reg_mse)
print("Random Forest Regression MSE:", random_forest_reg_mse)
print("Gradient Boosting Regression MSE:", gradient_boost_reg_mse)
print("SVR MSE:", svr_mse)
print("MLP Regression MSE:", mlp_reg_mse)

# Generate predictions from the Random Forest model
predictions = random_forest_reg.predict(new_df2)

# Create a DataFrame with the predictions
df_predictions_6 = pd.DataFrame(predictions, columns=['Stunted_Rate'])

df_predictions_6.head(200)
# Out:
# 28.56220465301253
# /opt/conda/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:216: LinAlgWarning: Ill-conditioned matrix (rcond=7.91767e-18): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# /opt/conda/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.458e+06, tolerance: 3.044e+02
#   model = cd_fast.enet_coordinate_descent(
# /opt/conda/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.456e+06, tolerance: 3.044e+02
#   model = cd_fast.enet_coordinate_descent(
# ...

# %%
df = pd.concat([df_predictions_mean, df_predictions_median,df_predictions_3,df_predictions_4,df_predictions_5,df_predictions_6],axis=1)

# %%
df.head()
# Out:
#     Mean_BMI  Median_BMI  Unmet_Need_Rate  Under5_Mortality_Rate  \
# 0  25.590246   24.647781        17.605185                 1.5542
# 1  24.351282   24.079521        34.258900                 5.4435
# 2  25.712790   24.835842        43.209900                 1.6144
# 3  24.574885   24.494444        19.881300                 1.5371
# 4  25.214574   25.001463        18.189290                 3.9682
#
#    Skilled_Birth_Attendant_Rate  Stunted_Rate
# 0                     80.733769     29.428856
# 1                     61.512544     21.686388
# 2                     63.194345     18.122939
# 3                     80.138052     32.558036
# 4                     65.538222     25.987747
